# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
pip install seaborn --upgrade
# Out:
# Requirement already satisfied: seaborn in c:\data python\lib\site-packages (0.13.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\data python\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\data python\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\data python\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\data python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\data python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\data python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\data python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\data python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\data python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\data python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\data python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\data python\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\data python\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\data python\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
df= sns.load_dataset("iris")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df= sns.load_dataset("iris")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
### Line plot 
sns.lineplot(x='sepal_length', y='sepal_width', data=df,hue='species')
plt.show()

# %%
### Line plot 
sns.lineplot(x='sepal_length', y='sepal_width', data=df,hue='species')
plt.show()

# %%
# continuous and categorical feature
sns.lineplot(x='sepal_width', y='species', data=df, hue='species')
plt.show()

# %%
## Scatter plot
sns.scatterplot(x='sepal_length',y='sepal_width',data=df, hue='species')
plt.title("Scatter plot")
plt.show()

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
## Bar plot (categorical estimate plot)
##A barplot is basically used to aggregate the categorical data according to some methods and by default its the mean. 
##It can also be understood as a visualization of the group by action. 
#To use this plot we choose a categorical column for 
##the x axis and a numerical column for the y axis and we see that it 
# creates a plot taking a mean per categorical column. 

sns.barplot(x='species', y='sepal_length', data=df,hue='species')
plt.show()

# %%
## Count Plot  value_count()
##A countplot basically counts the categories and returns a 
# count of their occurrences. 
sns.countplot(x='species', data=df,hue='species')
plt.show()

# %%
## Box plot
##A boxplot is sometimes known as the box and whisker plot.It shows the 
#distribution of the quantitative data 
## that represents the comparisons between variables. boxplot shows the 
#quartiles of the dataset while the whiskers extend to
## show the rest of the distribution i.e. the dots indicating the 
#presence  of outliers.
sns.boxplot(x='sepal_width',data=df,)
plt.show()

# %%
sns.boxplot(x='species', y='sepal_width', data=df)
plt.show()
# Checking outliers in each category with respect to sepal width.

# %%
## Violinplot
## It is similar to the boxplot except that it provides a higher, more advanced visualization and uses the kernel 
##density estimation to give a better description about the data distribution.

sns.violinplot(x='species', y='sepal_width', data=df)
plt.show()

# %%
##Stripplot
## It basically creates a scatter plot based on the category. 
# It is created using the stripplot()
sns.stripplot(x='species', y='petal_width', data=df)
plt.show()

# %%
## Histogram
## A histogram is basically used to represent data provided in a form of some groups.
## It is accurate method for the graphical representation of numerical data 
## distribution
sns.histplot(x='petal_width', data=df)
plt.show()

# %%
sns.histplot(x='petal_width', data=df,hue='species', kde=True) # kernel density estimation 
plt.show()
#kde is approximation of histogram to density curve.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['petal_width'],color="g",hist=True, kde=False)
plt.show()

# %%
##Pairplot
##Pairplot represents pairwise relation across the entire dataframe and supports an 

## additional  argument called hue for categorical separation. 
#What it does basically is create a jointplot between every possible numerical 
##column and takes a while if the dataframe is really huge

sns.pairplot(data=df, hue='species')
plt.show()

# %%
# categorical plot
sns.catplot(x='sepal_length', data=df, kind='violin') #box
plt.show()

# %%
#The default representation of the data in catplot() uses a stripplot
sns.catplot(x='species', y='sepal_length', data=df, kind='swarm')
plt.show()
